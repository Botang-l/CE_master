# %%
import re

# %%
lists = [8,2,15,5,14,16,3,0,7,4,1,12,9,13,11,10,6]
state = {}
for i in range(len(lists)):
    state[i+1] = lists[i]
# Out:
# {1: 8,
#  2: 2,
#  3: 15,
#  4: 5,
#  5: 14,
#  6: 16,
#  7: 3,
#  8: 0,
#  9: 7,
#  10: 4,
#  11: 1,
#  12: 12,
#  13: 9,
#  14: 13,
#  15: 11,
#  16: 10,
#  17: 6}

# %%
ans ='''
第 1 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 7 ； 出發時間 : 7 : 25 ； 到達時間 : 9 : 42
第 1 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 7 ； 到達站 : 1 ； 出發時間 : 10 : 27 ； 到達時間 : 12 : 48
第 1 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 3 ； 出發時間 : 13 : 17 ； 到達時間 : 16 : 21
第 2 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 3 ； 到達站 : 1 ； 出發時間 : 14 : 24 ； 到達時間 : 17 : 44
第 2 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 5 ； 出發時間 : 18 : 34 ； 到達時間 : 20 : 19
第 2 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 5 ； 到達站 : 1 ； 出發時間 : 20 : 43 ； 到達時間 : 22 : 30
第 3 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 5 ； 出發時間 : 13 : 47 ； 到達時間 : 16 : 34
第 3 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 5 ； 到達站 : 1 ； 出發時間 : 17 : 5 ； 到達時間 : 20 : 8
第 3 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 4 ； 出發時間 : 20 : 12 ； 到達時間 : 21 : 48
第 4 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 4 ； 到達站 : 1 ； 出發時間 : 6 : 25 ； 到達時間 : 7 : 48
第 4 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 7 ； 出發時間 : 8 : 4 ； 到達時間 : 10 : 37
第 4 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 7 ； 到達站 : 1 ； 出發時間 : 11 : 19 ； 到達時間 : 13 : 45
第 5 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 3 ； 出發時間 : 5 : 6 ； 到達時間 : 8 : 9
第 5 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 3 ； 到達站 : 1 ； 出發時間 : 9 : 5 ； 到達時間 : 12 : 6
第 6 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 13 ； 出發時間 : 5 : 1 ； 到達時間 : 5 : 21
第 6 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 13 ； 到達站 : 4 ； 出發時間 : 5 : 33 ； 到達時間 : 7 : 30
第 6 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 4 ； 到達站 : 1 ； 出發時間 : 7 : 55 ； 到達時間 : 9 : 43
第 7 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 4 ； 出發時間 : 14 : 14 ； 到達時間 : 15 : 10
第 7 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 4 ； 到達站 : 1 ； 出發時間 : 16 : 1 ； 到達時間 : 17 : 31
第 7 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 3 ； 出發時間 : 18 : 53 ； 到達時間 : 21 : 53
第 8 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 3 ； 到達站 : 1 ； 出發時間 : 13 : 29 ； 到達時間 : 16 : 39
第 8 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 4 ； 出發時間 : 16 : 59 ； 到達時間 : 19 : 55
第 8 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 4 ； 到達站 : 1 ； 出發時間 : 20 : 50 ； 到達時間 : 22 : 24
第 9 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 3 ； 出發時間 : 17 : 10 ； 到達時間 : 20 : 26
第 9 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 3 ； 到達站 : 13 ； 出發時間 : 20 : 56 ； 到達時間 : 23 : 28
第 10 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 13 ； 到達站 : 3 ； 出發時間 : 5 : 3 ； 到達時間 : 7 : 35
第 10 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 3 ； 到達站 : 1 ； 出發時間 : 7 : 57 ； 到達時間 : 11 : 12
第 11 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 4 ； 出發時間 : 15 : 18 ； 到達時間 : 18 : 30
第 11 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 4 ； 到達站 : 1 ； 出發時間 : 19 : 52 ； 到達時間 : 21 : 24
第 11 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 4 ； 出發時間 : 21 : 42 ； 到達時間 : 23 : 3
第 12 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 4 ； 到達站 : 1 ； 出發時間 : 10 : 21 ； 到達時間 : 11 : 45
第 12 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 :
個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 7 ； 出發時間 : 16 : 11 ； 到達時間 : 18 : 47
第 50 個工作班的第 3 個乘務之列車資訊 ====> ； 出發站 : 7 ； 到達站 : 1 ； 出發時間 : 19 : 14 ； 到達時間 : 21 : 41
第 51 個工作班的第 1 個乘務之列車資訊 ====> ； 出發站 : 1 ； 到達站 : 3 ； 出發時間 : 7 : 11 ； 到達時間 : 10 : 22
第 51 個工作班的第 2 個乘務之列車資訊 ====> ； 出發站 : 3 ； 到達站 : 1 ； 出發時間 : 10 : 47 ； 到達時間 : 14 : 2
'''
ans = re.findall('\d+',ans)
temp_ans = []
for i in ans:
    temp_ans.append(int(i))
ans = temp_ans
lists = []
lists_name = []
cons = 0
temp_list = []
temp_list_name = []
for i in (range(int(len(ans)/6))):
    if (ans[6*i+1] > cons):
        temp_list.append([state[ans[6*i+2]],state[ans[6*i+3]]])
        temp_list_name.append([ans[6*i+4],ans[6*i+5]])
        cons = ans[6*i+1]
    else:
        lists.append(temp_list) 
        lists_name.append(temp_list_name)
        temp_list = []
        temp_list_name = []
        temp_list.append([state[ans[6*i+2]],state[ans[6*i+3]]])
        temp_list_name.append([ans[6*i+4],ans[6*i+5]])
        cons = ans[6*i+1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\uscc_carl\Desktop\ORA\code\read.ipynb Cell 10 in <cell line: 153>()
#     <a href='vscode-notebook-cell:/c%3A/Users/uscc_carl/Desktop/ORA/code/read.ipynb#X11sZmlsZQ%3D%3D?line=160'>161</a> temp_list = []
#     <a href='vscode-notebook-cell:/c%3A/Users/uscc_carl/Desktop/ORA/code/read.ipynb#X11sZmlsZQ%3D%3D?line=161'>162</a> temp_list_name = []
# --> <a href='vscode-notebook-cell:/c%3A/Users/uscc_carl/Desktop/ORA/code/read.ipynb#X11sZmlsZQ%3D%3D?line=162'>163</a> temp_list.append([state[ans[6*i+2]],state[ans[6*i+3]]])
#     <a href='vscode-notebook-cell:/c%3A/Users/uscc_carl/Desktop/ORA/code/read.ipynb#X11sZmlsZQ%3D%3D?line=163'>164</a> temp_list_name.append([ans[6*i+4],ans[6*i+5]])
#     <a href='vscode-notebook-cell:/c%3A/Users/uscc_carl/Desktop/ORA/code/read.ipynb#X11sZmlsZQ%3D%3D?line=164'>165</a> cons = ans[6*i+1]
#
# ...

# %%
for i in range(len(lists)):
    plot(lists[i],lists_name[i],i)
# Out:
# [8, 3, 3, 8, 8, 2]

# %%
import matplotlib.pyplot as plt

# %%
def plot(a,b,number):
    Name = {
        1:'基隆',
        2:'七堵',
        3:'后里',
        4:'台中',
        5:'彰化',
        6:'斗六',
        7:'民雄',
        8:'嘉義',
        9:'新營',
        10:'善化',
        11:'台南',
        12:'新左營',
        13:'高雄',
        14:'屏東',
        15:'潮州',
        16:'枋寮'
        }
    x = []
    y = []
    l = []
    a_x = [i for it in a for i in it]
    b_x = [i for it in b for i in it]
    for i in a:
        x.append(i[0])
        x.append(i[0])
        x.append(i[1])
        x.append(i[1])
    del(x[0])
    del(x[-1])

    for i in list(range(1,len(a)+1))[::-1]:
        y.append(i)
        y.append(i)
        y.append(i)
        y.append(i)
    del(y[0])
    del(y[1])

    for i,v in enumerate(list(range(1,len(a)+1))[::-1]):
        l.append([a_x[2*i],v])
        l.append([a_x[2*i+1],v])
    
    plt.cla()
    for i,v in enumerate(l):
        plt.text(v[0]+0.01, v[1]+0.03, b_x[i], fontsize=10, color='green')
    plt.title('crew scheduling : '+str(number+1))
    plt.plot(x, y) 
    print(x)
    plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei'] 
    tick = []
    for i in x:
        tick.append(Name[i]) 
    plt.xticks(x, tick)
    plt.savefig('crew_scheduling_%d.png'%number)
